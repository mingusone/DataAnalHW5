# %%
#This is just me playing around with matplotlib trying to understand how error bars work.

import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
x = np.arange(5)
y =[1,2,0,0.5,1.5]
yerr = list(map(lambda x: x*0.5, [1,2,1,2,1]))

print(yerr)
# plt.errorbar(x, y + 3, yerr=yerr, label='both limits (default)', color="red")

# plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label='uplims=True', color="blue")

# plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
#              label='uplims=True, lolims=True', color="red")

# upperlimits = [True, False] * 5
# lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=5, lolims=5, label='subsets of uplims and lolims', color="blue")

plt.legend(loc='lower right')

plt.show()
# Out:
# [0.5, 1.0, 0.5, 1.0, 0.5]
